# %%
from IPython.display import Markdown, display

temperatures = [2, 5, 4, 6, 7, 3, 1]

avg_temp = sum(temperatures) / len(temperatures)
max_temp = max(temperatures)
min_temp = min(temperatures)
diff_temp = max_temp - min_temp

display(Markdown(f"""
| Показник | Значення |
| :--- | :--- |
| Середня температура | {avg_temp} |
| Максимальна температура | {max_temp} |
| Мінімальна температура | {min_temp} |
| Різниця (Max - Min) | {diff_temp} |
"""))
# Out:
# | Показник | Значення |
# | :--- | :--- |
# | Середня температура | 4.0 |
# | Максимальна температура | 7 |
# | Мінімальна температура | 1 |
# | Різниця (Max - Min) | 6 |
